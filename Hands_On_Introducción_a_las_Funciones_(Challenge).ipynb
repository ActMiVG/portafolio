# %% [markdown]
# <a href="https://colab.research.google.com/github/ActMiVG/portafolio/blob/main/Hands_On_Introducci%C3%B3n_a_las_Funciones_(Challenge).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función

print('Hola mundo!')
# Out:
# Hola mundo!

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función

len([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función

sorted([2, 4, 1, 5, 3])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función

round(3.14159265, 4)
# Out:
# 3.1416

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función

min((3, 6, 7, 2, 10, 2))
# Out:
# 2

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función

num_cuad = int(input('Ingresa un número: '))

def cuadrado(numero):
    return numero ** 2

cuadrado(num_cuad)
# Out:
# 36

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función

num_par = int(input('Ingresa un número: '))

def par(numero):
    if numero % 2 == 0:
        print('Par')
    else:
        print('Impar')

par(num_par)
# Out:
# Ingresa un número: 4
# Par

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función

num_fact = int(input('Ingresa un número: '))

def factorial(numero):
    if numero == 0:
        return 1
    else:
        return numero * factorial(numero - 1)

factorial(num_fact)
# Out:
# 120

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas

lista_1 = [1, 2]
lista_2 = [3, 4, 5]

# %%
# difinir función

def unir(lista1, lista2):
    lista_unida = lista1 + lista2
    return lista_unida

unir(lista_1, lista_2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario

diccionario = {'México': 'Toluca', 'Monterrey': 'Nuevo León', 'Jalisco': 'Guadalajara'}

# %%
# difinir función

clave = input('Ingrese una clave: ')

def buscar(diccionario, clave):
    return diccionario.get(clave)

buscar(diccionario, clave)
# Out:
# Ingrese una clave: Jalisco
# 'Guadalajara'

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda
agenda_contactos = {
    1: {'nombre': 'Misael', 'telefono': 5512345678, 'correo': 'corre1@mail.com'},
    2: {'nombre': 'Ana', 'telefono': 5512345679, 'correo': 'corre2@mail.com'},
    3: {'nombre': 'María', 'telefono': 5512345670, 'correo': 'corre3@mail.com'},
    4: {'nombre': 'Pedro', 'telefono': 5512345671, 'correo': 'corre4@mail.com'},
    5: {'nombre': 'Luis', 'telefono': 5512345672, 'correo': 'corre5@mail.com'},
    6: {'nombre': 'Sofía', 'telefono': 55123456783, 'correo': 'corre6@mail.com'},
    7: {'nombre': 'Carlos', 'telefono': 55123456784, 'correo': 'corre7@mail.com'}
}

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones
def mostrar_menu() -> str:
  menu = """
  ************************
   Menú CRUD - Agenda:

   1. Ver agenda
   2. Crear contacto
   3. Consultar contacto
   4. Actualizar contacto
   5. Eliminar contacto
   6. Salir menú
  ************************
   """
  print(menu)

mostrar_menu()
# Out:
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda
def mostrar_agenda(agenda):
  for i in enumerate(agenda.values(), 1):
    print(f"No: {i[0]}\n Nombre: {i[1]['nombre']}\n Teléfono: {i[1]['telefono']}\n Correo: {i[1]['correo']}\n")

mostrar_agenda(agenda = agenda_contactos)
# Out:
# No: 1
#  Nombre: Misael
#  Teléfono: 5512345678
#  Correo: corre1@mail.com
#
# No: 2
#  Nombre: Ana
#  Teléfono: 5512345679
#  Correo: corre2@mail.com
#
# No: 3
#  Nombre: María
#  Teléfono: 5512345670
#  Correo: corre3@mail.com
#
# No: 4
#  Nombre: Pedro
#  Teléfono: 5512345671
#  Correo: corre4@mail.com
#
# No: 5
#  Nombre: Luis
#  Teléfono: 5512345672
#  Correo: corre5@mail.com
#
# No: 6
#  Nombre: Sofía
#  Teléfono: 55123456783
#  Correo: corre6@mail.com
#
# No: 7
#  Nombre: Carlos
#  Teléfono: 55123456784
#  Correo: corre7@mail.com

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
# Crear función crear contacto
def crear_contacto(agenda: dict):
  print("Crear contacto")
  nuevo_nombre = input("Ingresa el nombre del nuevo contacto: ")
  nuevo_telefono = int(input("Ingresa el teléfono del nuevo contacto: "))
  nuevo_correo = input("Ingresa el correo del nuevo contacto: ")

  nueva_clave = max(agenda.keys()) + 1
  agenda[nueva_clave] = {'nombre': nuevo_nombre, 'telefono': nuevo_telefono, 'correo': nuevo_correo}
  print("\nContacto creado con éxito")

crear_contacto(agenda = agenda_contactos)
# Out:
# Crear contacto
# Ingresa el nombre del nuevo contacto: Roxana
# Ingresa el teléfono del nuevo contacto: 0123456789
# Ingresa el correo del nuevo contacto: rox@email.com
#
# Contacto creado con éxito

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto
def consultar_contacto(agenda: dict):
  encontrado = False
  claves = list(agenda.keys())
  print("Consultar contacto")
  nombre = input("Ingresa el nombre del contacto a consultar: ")
  for i in enumerate(agenda.values(), 1):
    if i[1]['nombre'].lower() == nombre.lower():
      id = claves[i[0]-1]
      print("Contacto encontrado")
      print(f"\nID: {id}\n Nombre: {agenda[id]['nombre']}\n Teléfono: {agenda[id]['telefono']}\n Correo: {agenda[id]['correo']}\n\n")
      encontrado = True

  if encontrado == False:
    print("Contacto no encontrado")

consultar_contacto(agenda = agenda_contactos)
# Out:
# Consultar contacto
# Ingresa el nombre del contacto a consultar: roxana
# Contacto encontrado
#
# ID: 8
#  Nombre: Roxana
#  Teléfono: 123456789
#  Correo: rox@email.com

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto
def mostrar_menu_ac() -> str:
  menu = """
  ***************************
   Menú actualizar contacto:

   1. Actualizar nombre
   2. Actualizar teléfono
   3. Actualziar correo
   4. Salir del menú
  ***************************
   """
  print(menu)

mostrar_menu_ac()
# Out:
#   ***************************
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#   ***************************

# %% [markdown]
#  * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
def buscar_contacto(agenda: dict) -> int:
  encontrado = False
  claves = list(agenda.keys())
  nombre = input("Ingresa el nombre del contacto: ")
  for i in enumerate(agenda.values(), 1):
    if i[1]['nombre'].lower() == nombre.lower():
      encontrado = True
      return  claves[i[0]-1]
  if encontrado == False:
    return None

buscar_contacto(agenda = agenda_contactos)
# Out:
# Ingresa el nombre del contacto: carlos
# 7

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
def actualizar_nombre(agenda: dict, id: int) -> str:
  print("Actualizar nombre")
  nuevo_nombre = input("Ingresa el nuevo nombre: ")
  agenda[id]['nombre'] = nuevo_nombre
  print(f"\nID: {id}\n Nombre: {agenda[id]['nombre']}\n Teléfono: {agenda[id]['telefono']}\n Correo: {agenda[id]['correo']}\n\n")

actualizar_nombre(agenda = agenda_contactos, id = 7)
# Out:
# Actualizar nombre
# Ingresa el nuevo nombre: Carlos Antonio
#
# ID: 7
#  Nombre: Carlos Antonio
#  Teléfono: 55123456784
#  Correo: corre7@mail.com

# %%
# Crear función actualizar telefono para actualizar contacto
def actualizar_telefono(agenda: dict, id: int) -> str:
  print("Actualizar teléfono")
  nuevo_nombre = input("Ingresa el nuevo teléfono: ")
  agenda[id]['telefono'] = nuevo_nombre
  print(f"\nID: {id}\n Nombre: {agenda[id]['nombre']}\n Teléfono: {agenda[id]['telefono']}\n Correo: {agenda[id]['correo']}\n\n")

actualizar_telefono(agenda = agenda_contactos, id = 7)
# Out:
# Actualizar teléfono
# Ingresa el nuevo teléfono: 5599999999
#
# ID: 7
#  Nombre: Carlos Antonio
#  Teléfono: 5599999999
#  Correo: corre7@mail.com

# %%
# Crear función actualizar correo para actualizar contacto
def actualizar_correo(agenda: dict, id: int) -> str:
  print("Actualizar correo")
  nuevo_correo = input("Ingresa el nuevo correo: ")
  agenda[id]['correo'] = nuevo_correo
  print(f"\nID: {id}\n Nombre: {agenda[id]['nombre']}\n Teléfono: {agenda[id]['telefono']}\n Correo: {agenda[id]['correo']}\n\n")

actualizar_correo(agenda = agenda_contactos, id = 7)
# Out:
# Actualizar correo
# Ingresa el nuevo correo: ca@email.com
#
# ID: 7
#  Nombre: Carlos Antonio
#  Teléfono: 5599999999
#  Correo: ca@email.com

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
def actualizar_contacto(agenda: dict):
  print("Actualizar contacto")

  id = buscar_contacto(agenda)
  if id is None:
    print("Contacto no encontrado")
  else:
    mostrar_menu_ac()
    while True:
      opcion = int(input("Elige una opción: "))
      if opcion == 1:
          actualizar_nombre(agenda, id)
      elif opcion == 2:
          actualizar_telefono(agenda, id)
      elif opcion == 3:
          actualizar_correo(agenda, id)
      elif opcion == 4:
        print("Saliendo del menú de actualización")
        break
      else:
        print("Opción no encontrada")


actualizar_contacto(agenda = agenda_contactos)
# Out:
# Actualizar contacto
# Ingresa el nombre del contacto: carlos antonio
#
#   ***************************
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#   ***************************
#
# Elige una opción: 2
# Actualizar teléfono
# Ingresa el nuevo teléfono: 5588888888
#
# ID: 7
#  Nombre: Carlos Antonio
#  Teléfono: 5588888888
#  Correo: ca@email.com
#
#
# Elige una opción: 4
# Saliendo del menú de actualización

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
def eliminar_contacto(agenda: dict):
  print("Eliminar contacto")

  id = buscar_contacto(agenda)
  if id is None:
    print("Contacto no encontrado")
  else:
    agenda.pop(id)
    print("Contacto eliminado")

eliminar_contacto(agenda = agenda_contactos)
# Out:
# Eliminar contacto
# Ingresa el nombre del contacto: pedro
# Contacto eliminado

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
def crud_agenda(agenda: dict):
  while True:
    mostrar_menu()
    opcion = int(input("Elige una opción: "))
    if opcion == 1:
      mostrar_agenda(agenda = agenda)
    elif opcion == 2:
      crear_contacto(agenda = agenda)
    elif opcion == 3:
      consultar_contacto(agenda = agenda)
    elif opcion == 4:
      actualizar_contacto(agenda = agenda)
    elif opcion == 5:
      eliminar_contacto(agenda = agenda)
    elif opcion == 6:
      print("Saliendo del menú")
      break
    else:
      print("Opción no encontrada")


crud_agenda(agenda = agenda_contactos)
# Out:
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 1
# No: 1
#  Nombre: Misael
#  Teléfono: 5512345678
#  Correo: corre1@mail.com
#
# No: 2
#  Nombre: Ana
#  Teléfono: 5512345679
#  Correo: corre2@mail.com
#
# No: 3
#  Nombre: María
#  Teléfono: 5512345670
#  Correo: corre3@mail.com
#
# No: 4
#  Nombre: Luis
#  Teléfono: 5512345672
#  Correo: corre5@mail.com
#
# No: 5
#  Nombre: Sofía
#  Teléfono: 55123456783
#  Correo: corre6@mail.com
#
# No: 6
#  Nombre: Carlos Antonio
#  Teléfono: 5588888888
#  Correo: ca@email.com
#
# No: 7
#  Nombre: Roxana
#  Teléfono: 123456789
#  Correo: rox@email.com
#
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 2
# Crear contacto
# Ingresa el nombre del nuevo contacto: Ignacio
# Ingresa el teléfono del nuevo contacto: 777777777777
# Ingresa el correo del nuevo contacto: ignacio@emai.com
#
# Contacto creado con éxito
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 3
# Consultar contacto
# Ingresa el nombre del contacto a consultar: misael
# Contacto encontrado
#
# ID: 1
#  Nombre: Misael
#  Teléfono: 5512345678
#  Correo: corre1@mail.com
#
#
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 4
# Actualizar contacto
# Ingresa el nombre del contacto: ignacio
#
#   ***************************
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#   ***************************
#
# Elige una opción: 2
# Actualizar teléfono
# Ingresa el nuevo teléfono: 55555555555
#
# ID: 9
#  Nombre: Ignacio
#  Teléfono: 55555555555
#  Correo: ignacio@emai.com
#
#
# Elige una opción: 5
# Opción no encontrada
# Elige una opción: 4
# Saliendo del menú de actualización
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 5
# Eliminar contacto
# Ingresa el nombre del contacto: Ana
# Contacto eliminado
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 1
# No: 1
#  Nombre: Misael
#  Teléfono: 5512345678
#  Correo: corre1@mail.com
#
# No: 2
#  Nombre: María
#  Teléfono: 5512345670
#  Correo: corre3@mail.com
#
# No: 3
#  Nombre: Luis
#  Teléfono: 5512345672
#  Correo: corre5@mail.com
#
# No: 4
#  Nombre: Sofía
#  Teléfono: 55123456783
#  Correo: corre6@mail.com
#
# No: 5
#  Nombre: Carlos Antonio
#  Teléfono: 5588888888
#  Correo: ca@email.com
#
# No: 6
#  Nombre: Roxana
#  Teléfono: 123456789
#  Correo: rox@email.com
#
# No: 7
#  Nombre: Ignacio
#  Teléfono: 55555555555
#  Correo: ignacio@emai.com
#
#
#   ************************
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#   ************************
#
# Elige una opción: 6
# Saliendo del menú
